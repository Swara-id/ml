# %%
import os
import cv2
import mediapipe as mp
import pandas as pd
import numpy as np

def extract_hand_features(input_dir, output_filename):
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands(
        static_image_mode=True, max_num_hands=2, min_detection_confidence=0.5
    )

    data = []

    for filename in os.listdir(input_dir):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            image_path = os.path.join(input_dir, filename)
            image = cv2.imread(image_path)
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            results = hands.process(image_rgb)

            if results.multi_hand_landmarks:
                hand_landmarks_list = []
                for hand_landmarks in results.multi_hand_landmarks:
                    landmarks = []
                    for landmark in hand_landmarks.landmark:
                        landmarks.append(landmark.x)
                        landmarks.append(landmark.y)
                        landmarks.append(landmark.z)
                    hand_landmarks_list.append(landmarks)
                
                if len(hand_landmarks_list) == 2:
                    combined_landmarks = hand_landmarks_list[0] + hand_landmarks_list[1]
                else:
                    combined_landmarks = hand_landmarks_list[0] + hand_landmarks_list[0]
                
                print(len(combined_landmarks), len(hand_landmarks_list))
                print("Extracted features from", filename)
                data.append([filename] + combined_landmarks)

    hands.close()

    columns = ["filename"]
    for i in range(21 * 2):  # 21 landmarks for each of the two hands, each with x, y, z
        columns.append(f"x_{i}")
        columns.append(f"y_{i}")
        columns.append(f"z_{i}")

    df = pd.DataFrame(data, columns=columns)
    df.to_csv(output_filename, index=False)

# Directory paths
out_dir = "./datasets/Extraction-Feature-Default-126"
os.makedirs(out_dir, exist_ok=True)
DATA_DIR = './alphabets/bismillah-alphabet-dataset-resize/'

# Process each folder in the data directory
for files in os.listdir(DATA_DIR):
    if files != "M":
        continue
    input_dir = os.path.join(DATA_DIR, files)
    output_filename = os.path.join(out_dir, f"{files}.csv")
    extract_hand_features(input_dir, output_filename)
# Out:
# c:\Users\ahmad\AppData\Local\Programs\Python\Python39\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 126 2
# Extracted features from 45_02.mp4.jpg
# 126 2
# Extracted features from 46_02.mp4.jpg
# 126 1
# Extracted features from 47_02.mp4.jpg
# 126 1
# Extracted features from 48_02.mp4.jpg
# 126 1
# Extracted features from 49_02.mp4.jpg
# 126 2
# Extracted features from 50_02.mp4.jpg
# 126 2
# Extracted features from 51_02.mp4.jpg
# 126 2
# Extracted features from 52_02.mp4.jpg
# 126 2
# Extracted features from 53_02.mp4.jpg
# 126 2
# Extracted features from 54_02.mp4.jpg
# 126 2
# Extracted features from 55_02.mp4.jpg
# 126 2
# Extracted features from 56_02.mp4.jpg
# 126 2
# Extracted features from 57_02.mp4.jpg
# 126 2
# Extracted features from 58_02.mp4.jpg
# 126 2
# Extracted features from 59_02.mp4.jpg
# 126 2
# Extracted features from 60_02.mp4.jpg
# 126 2
# Extracted features from 61_02.mp4.jpg
# 126 2
# Extracted features from 62_02.mp4.jpg
# 126 2
# Extracted features from 63_02.mp4.jpg
# 126 2
# Extracted features from 64_02.mp4.jpg
# 126 2
# Extracted features from 65_02.mp4.jpg
# 126 2
# Extracted features from 66_02.mp4.jpg
# 126 2
# Extracted features from 67_02.mp4.jpg
# 126 2
# Extracted features from 68_02.mp4.jpg
# 126 2
# Extracted features from 69_02.mp4.jpg
# 126 2
# Extracted features from 70_02.mp4.jpg
# 126 2
# Extracted features from 71_02.mp4.jpg
# 126 2
# Extracted features from 72_02.mp4.jpg
# 126 2
# Extracted features from 73_02.mp4.jpg
# 126 2
# Extracted features from 74_02.mp4.jpg
# 126 2
# Extracted features from 75_02.mp4.jpg
# 126 2
# Extracted features from 76_02.mp4.jpg
# 126 2
# Extracted features from 77_02.mp4.jpg
# 126 2
# Extracted features from 78_02.mp4.jpg
# 126 2
# Extracted features from 79_02.mp4.jpg
# 126 2
# Extracted features from 80_02.mp4.jpg
# 126 2
# Extracted features from 81_02.mp4.jpg
# 126 2
# Extracted features from 82_02.mp4.jpg
# 126 2
# Extracted features from 83_02.mp4.jpg
# 126 2
# Extracted features from 84_02.mp4.jpg
# 126 2
# Extracted features from 85_02.mp4.jpg
# 126 2
# Extracted features from 86_02.mp4.jpg
# 126 2
# Extracted features from 87_02.mp4.jpg
# 126 2
# Extracted features from M_100.jpg
# 126 2
# Extracted features from M_101.jpg
# 126 2
# Extracted features from M_102.jpg
# 126 2
# Extracted features from M_104.jpg
# 126 2
# Extracted features from M_105.jpg
# 126 2
# Extracted features from M_106.jpg
# 126 2
# Extracted features from M_107.jpg
# 126 2
# Extracted features from M_108.jpg
# 126 2
# Extracted features from M_111.jpg
# 126 2
# Extracted features from M_112.jpg
# 126 2
# Extracted features from M_113.jpg
# 126 2
# Extracted features from M_114.jpg
# 126 2
# Extracted features from M_115.jpg
# 126 2
# Extracted features from M_116.jpg
# 126 2
# Extracted features from M_117.jpg
# 126 2
# Extracted features from M_119.jpg
# 126 2
# Extracted features from M_12.jpg
# 126 2
# Extracted features from M_120.jpg
# 126 2
# Extracted features from M_121.jpg
# 126 2
# Extracted features from M_123.jpg
# 126 2
# Extracted features from M_125.jpg
# 126 2
# Extracted features from M_13.jpg
# 126 2
# Extracted features from M_130.jpg
# 126 2
# Extracted features from M_131.jpg
# 126 2
# Extracted features from M_132.jpg
# 126 2
# Extracted features from M_133.jpg
# 126 2
# Extracted features from M_136.jpg
# 126 2
# Extracted features from M_137.jpg
# 126 2
# Extracted features from M_138.jpg
# 126 2
# Extracted features from M_139.jpg
# 126 2
# Extracted features from M_14.jpg
# 126 2
# Extracted features from M_140.jpg
# 126 2
# Extracted features from M_141.jpg
# 126 2
# Extracted features from M_142.jpg
# 126 2
# Extracted features from M_143.jpg
# 126 2
# Extracted features from M_15.jpg
# 126 2
# Extracted features from M_16.jpg
# 126 2
# Extracted features from M_164.jpg
# 126 2
# Extracted features from M_166.jpg
# 126 2
# Extracted features from M_168.jpg
# 126 2
# Extracted features from M_169.jpg
# 126 2
# Extracted features from M_170.jpg
# 126 1
# Extracted features from M_171.jpg
# 126 2
# Extracted features from M_173.jpg
# 126 2
# Extracted features from M_174.jpg
# 126 2
# Extracted features from M_175.jpg
# 126 2
# Extracted features from M_176.jpg
# 126 2
# Extracted features from M_177.jpg
# 126 2
# Extracted features from M_178.jpg
# 126 2
# Extracted features from M_179.jpg
# 126 2
# Extracted features from M_18.jpg
# 126 2
# Extracted features from M_180.jpg
# 126 2
# Extracted features from M_182.jpg
# 126 2
# Extracted features from M_184.jpg
# 126 2
# Extracted features from M_185.jpg
# 126 2
# Extracted features from M_187.jpg
# 126 2
# Extracted features from M_193.jpg
# 126 2
# Extracted features from M_196.jpg
# 126 2
# Extracted features from M_199.jpg
# 126 2
# Extracted features from M_200.jpg
# 126 2
# Extracted features from M_202.jpg
# 126 2
# Extracted features from M_203.jpg
# 126 1
# Extracted features from M_204.jpg
# 126 2
# Extracted features from M_207.jpg
# 126 2
# Extracted features from M_21.jpg
# 126 2
# Extracted features from M_218.jpg
# 126 2
# Extracted features from M_219.jpg
# 126 2
# Extracted features from M_22.jpg
# 126 2
# Extracted features from M_220.jpg
# 126 2
# Extracted features from M_221.jpg
# 126 2
# Extracted features from M_222.jpg
# 126 2
# Extracted features from M_223.jpg
# 126 2
# Extracted features from M_224.jpg
# 126 2
# Extracted features from M_225.jpg
# 126 2
# Extracted features from M_229.jpg
# 126 2
# Extracted features from M_23.jpg
# 126 2
# Extracted features from M_230.jpg
# 126 2
# Extracted features from M_231.jpg
# 126 2
# Extracted features from M_232.jpg
# 126 2
# Extracted features from M_234.jpg
# 126 2
# Extracted features from M_235.jpg
# 126 2
# Extracted features from M_236.jpg
# 126 2
# Extracted features from M_239.jpg
# 126 2
# Extracted features from M_24.jpg
# 126 2
# Extracted features from M_25.jpg
# 126 2
# Extracted features from M_252.jpg
# 126 2
# Extracted features from M_26.jpg
# 126 2
# Extracted features from M_27.jpg
# 126 2
# Extracted features from M_28.jpg
# 126 2
# Extracted features from M_29.jpg
# 126 2
# Extracted features from M_3.jpg
# 126 2
# Extracted features from M_30.jpg
# 126 2
# Extracted features from M_31.jpg
# 126 2
# Extracted features from M_32.jpg
# 126 2
# Extracted features from M_33.jpg
# 126 2
# Extracted features from M_34.jpg
# 126 2
# Extracted features from M_35.jpg
# 126 2
# Extracted features from M_36.jpg
# 126 2
# Extracted features from M_37.jpg
# 126 2
# Extracted features from M_38.jpg
# 126 2
# Extracted features from M_39.jpg
# 126 2
# Extracted features from M_4.jpg
# 126 2
# Extracted features from M_40.jpg
# 126 2
# Extracted features from M_41.jpg
# 126 2
# Extracted features from M_42.jpg
# 126 2
# Extracted features from M_43.jpg
# 126 2
# Extracted features from M_44.jpg
# 126 2
# Extracted features from M_45.jpg
# 126 2
# Extracted features from M_46.jpg
# 126 2
# Extracted features from M_47.jpg
# 126 2
# Extracted features from M_49.jpg
# 126 2
# Extracted features from M_5.jpg
# 126 2
# Extracted features from M_50.jpg
# 126 2
# Extracted features from M_51.jpg
# 126 2
# Extracted features from M_52.jpg
# 126 2
# Extracted features from M_53.jpg
# 126 2
# Extracted features from M_54.jpg
# 126 2
# Extracted features from M_55.jpg
# 126 2
# Extracted features from M_56.jpg
# 126 2
# Extracted features from M_57.jpg
# 126 2
# Extracted features from M_58.jpg
# 126 2
# Extracted features from M_59.jpg
# 126 2
# Extracted features from M_61.jpg
# 126 2
# Extracted features from M_62.jpg
# 126 2
# Extracted features from M_63.jpg
# 126 2
# Extracted features from M_64.jpg
# 126 2
# Extracted features from M_65.jpg
# 126 2
# Extracted features from M_66.jpg
# 126 2
# Extracted features from M_67.jpg
# 126 2
# Extracted features from M_68.jpg
# 126 2
# Extracted features from M_69.jpg
# 126 2
# Extracted features from M_7.jpg
# 126 2
# Extracted features from M_70.jpg
# 126 2
# Extracted features from M_71.jpg
# 126 2
# Extracted features from M_72.jpg
# 126 2
# Extracted features from M_74.jpg
# 126 2
# Extracted features from M_75.jpg
# 126 2
# Extracted features from M_76.jpg
# 126 2
# Extracted features from M_77.jpg
# 126 2
# Extracted features from M_79.jpg
# 126 2
# Extracted features from M_8.jpg
# 126 2
# Extracted features from M_81.jpg
# 126 2
# Extracted features from M_82.jpg
# 126 2
# Extracted features from M_83.jpg
# 126 2
# Extracted features from M_85.jpg
# 126 1
# Extracted features from M_86.jpg
# 126 2
# Extracted features from M_87.jpg
# 126 2
# Extracted features from M_88.jpg
# 126 2
# Extracted features from M_89.jpg
# 126 2
# Extracted features from M_9.jpg
# 126 2
# Extracted features from M_90.jpg
# 126 2
# Extracted features from M_91.jpg
# 126 2
# Extracted features from M_92.jpg
# 126 2
# Extracted features from M_94.jpg
# 126 2
# Extracted features from M_95.jpg
# 126 2
# Extracted features from M_96.jpg
# 126 2
# Extracted features from M_97.jpg
# 126 2
# Extracted features from M_98.jpg
# 126 2
# Extracted features from M_99.jpg
